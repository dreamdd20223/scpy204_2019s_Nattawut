# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv("covid.csv")
data
country = data[data["countriesAndTerritories"]=="Thailand"]
dataframe = country.iloc[:,4:7]
dataframe
# Out:
#       cases  deaths countriesAndTerritories
# 9427     33       3                Thailand
# 9428     45       2                Thailand
# 9429     50       1                Thailand
# 9430     54       2                Thailand
# 9431    111       4                Thailand
# ...     ...     ...                     ...
# 9519      0       0                Thailand
# 9520      0       0                Thailand
# 9521      0       0                Thailand
# 9522      0       0                Thailand
# 9523      0       0                Thailand
#
# [97 rows x 3 columns]

# %%
x=sum(dataframe["deaths"])
print ("deads are",x)
# Out:
# deads are 38

# %%
y=sum(dataframe["cases"])
print ("cases are",y)
# Out:
# cases are 2551

# %%
z= (x*100)/y
print("The percentage of deads and cases in Thailand is " ,z)
# Out:
# The percentage of deads and cases in Thailand is  1.4896119168953352

# %%
w=(x*100)/69428524
print("The percentage of deads and whole people in Thailand is",w)
# Out:
# The percentage of deads and whole people in Thailand is 5.473254767737825e-05

# %%
import matplotlib.pyplot as plt

# %%
Thailand = data[data.countriesAndTerritories =='Thailand']
Thailand
# Out:
#          dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 9427  12/04/2020   12      4  2020     33       3                Thailand
# 9428  11/04/2020   11      4  2020     45       2                Thailand
# 9429  10/04/2020   10      4  2020     50       1                Thailand
# 9430  09/04/2020    9      4  2020     54       2                Thailand
# 9431  08/04/2020    8      4  2020    111       4                Thailand
# ...          ...  ...    ...   ...    ...     ...                     ...
# 9519  04/01/2020    4      1  2020      0       0                Thailand
# 9520  03/01/2020    3      1  2020      0       0                Thailand
# 9521  02/01/2020    2      1  2020      0       0                Thailand
# 9522  01/01/2020    1      1  2020      0       0                Thailand
# 9523  31/12/2019   31     12  2019      0       0                Thailand
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
Thailand = data[data.countriesAndTerritories =='Thailand']
th = Thailand.loc[:]
th['cases'] = Thailand['cases'].cumsum()
th
# Out:
#          dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 9427  12/04/2020   12      4  2020     33       3                Thailand
# 9428  11/04/2020   11      4  2020     78       2                Thailand
# 9429  10/04/2020   10      4  2020    128       1                Thailand
# 9430  09/04/2020    9      4  2020    182       2                Thailand
# 9431  08/04/2020    8      4  2020    293       4                Thailand
# ...          ...  ...    ...   ...    ...     ...                     ...
# 9519  04/01/2020    4      1  2020   2551       0                Thailand
# 9520  03/01/2020    3      1  2020   2551       0                Thailand
# 9521  02/01/2020    2      1  2020   2551       0                Thailand
# 9522  01/01/2020    1      1  2020   2551       0                Thailand
# 9523  31/12/2019   31     12  2019   2551       0                Thailand
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
China = data[data.countriesAndTerritories =='China']
China
China = data[data.countriesAndTerritories =='China']
Ch = China.loc[:]
Ch['cases'] = China['cases'].cumsum()
Ch
# Out:
#          dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 2009  12/04/2020   12      4  2020     93       0                   China
# 2010  11/04/2020   11      4  2020    172       3                   China
# 2011  10/04/2020   10      4  2020    227       1                   China
# 2012  09/04/2020    9      4  2020    313       2                   China
# 2013  08/04/2020    8      4  2020    399       2                   China
# ...          ...  ...    ...   ...    ...     ...                     ...
# 2108  04/01/2020    4      1  2020  83053       0                   China
# 2109  03/01/2020    3      1  2020  83070       0                   China
# 2110  02/01/2020    2      1  2020  83070       0                   China
# 2111  01/01/2020    1      1  2020  83070       0                   China
# 2112  31/12/2019   31     12  2019  83097       0                   China
#
#      geoId countryterritoryCode   popData2018
# ...

# %%
Japan = data[data.countriesAndTerritories =='Japan']
Jp = Japan.loc[:]
Jp['cases'] = Japan['cases'].cumsum()
Jp
# Out:
#          dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 5127  12/04/2020   12      4  2020   1401      10                   Japan
# 5128  11/04/2020   11      4  2020   2081       3                   Japan
# 5129  10/04/2020   10      4  2020   2491       4                   Japan
# 5130  09/04/2020    9      4  2020   2842       1                   Japan
# 5131  08/04/2020    8      4  2020   2931       0                   Japan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 5226  04/01/2020    4      1  2020   6748       0                   Japan
# 5227  03/01/2020    3      1  2020   6748       0                   Japan
# 5228  02/01/2020    2      1  2020   6748       0                   Japan
# 5229  01/01/2020    1      1  2020   6748       0                   Japan
# 5230  31/12/2019   31     12  2019   6748       0                   Japan
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
Japan = data[data.countriesAndTerritories =='Japan']
Japan
# Out:
#          dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 5127  12/04/2020   12      4  2020   1401      10                   Japan
# 5128  11/04/2020   11      4  2020    680       3                   Japan
# 5129  10/04/2020   10      4  2020    410       4                   Japan
# 5130  09/04/2020    9      4  2020    351       1                   Japan
# 5131  08/04/2020    8      4  2020     89       0                   Japan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 5226  04/01/2020    4      1  2020      0       0                   Japan
# 5227  03/01/2020    3      1  2020      0       0                   Japan
# 5228  02/01/2020    2      1  2020      0       0                   Japan
# 5229  01/01/2020    1      1  2020      0       0                   Japan
# 5230  31/12/2019   31     12  2019      0       0                   Japan
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
Canada = data[data.countriesAndTerritories =='Canada']
Canada
Canada = data[data.countriesAndTerritories =='Canada']
Ca = Canada.loc[:]
Ca['cases'] = Canada['cases'].cumsum()
Ca
# Out:
#          dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 1703  12/04/2020   12      4  2020   1168      84                  Canada
# 1704  11/04/2020   11      4  2020   2553      60                  Canada
# 1705  10/04/2020   10      4  2020   4027      74                  Canada
# 1706  09/04/2020    9      4  2020   5418      55                  Canada
# 1707  08/04/2020    8      4  2020   6648      57                  Canada
# ...          ...  ...    ...   ...    ...     ...                     ...
# 1802  04/01/2020    4      1  2020  23301       0                  Canada
# 1803  03/01/2020    3      1  2020  23301       0                  Canada
# 1804  02/01/2020    2      1  2020  23301       0                  Canada
# 1805  01/01/2020    1      1  2020  23301       0                  Canada
# 1806  31/12/2019   31     12  2019  23301       0                  Canada
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
Brazil = data[data.countriesAndTerritories =='Brazil']
Brazil
Bra = Brazil.loc[:]
Bra['cases'] = Brazil['cases'].cumsum()
Bra
# Out:
#          dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 1349  12/04/2020   12      4  2020   1089      68                  Brazil
# 1350  11/04/2020   11      4  2020   2870     115                  Brazil
# 1351  10/04/2020   10      4  2020   4800     141                  Brazil
# 1352  09/04/2020    9      4  2020   7010     133                  Brazil
# 1353  08/04/2020    8      4  2020   8671     114                  Brazil
# ...          ...  ...    ...   ...    ...     ...                     ...
# 1445  04/01/2020    4      1  2020  20727       0                  Brazil
# 1446  03/01/2020    3      1  2020  20727       0                  Brazil
# 1447  02/01/2020    2      1  2020  20727       0                  Brazil
# 1448  01/01/2020    1      1  2020  20727       0                  Brazil
# 1449  31/12/2019   31     12  2019  20727       0                  Brazil
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
Laos = data[data.countriesAndTerritories =='Laos']
Laos
La = Laos.loc[:]
La['cases'] = Laos['cases'].cumsum()
La
# Out:
#          dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 5499  12/04/2020   12      4  2020      2       0                    Laos
# 5500  11/04/2020   11      4  2020      2       0                    Laos
# 5501  10/04/2020   10      4  2020      3       0                    Laos
# 5502  09/04/2020    9      4  2020      6       0                    Laos
# 5503  08/04/2020    8      4  2020      6       0                    Laos
# 5504  07/04/2020    7      4  2020      7       0                    Laos
# 5505  06/04/2020    6      4  2020      8       0                    Laos
# 5506  05/04/2020    5      4  2020      8       0                    Laos
# 5507  04/04/2020    4      4  2020      8       0                    Laos
# 5508  03/04/2020    3      4  2020      8       0                    Laos
# 5509  02/04/2020    2      4  2020      9       0                    Laos
# 5510  01/04/2020    1      4  2020      9       0                    Laos
# ...

# %%
Vietnam = data[data.countriesAndTerritories =='Vietnam']
Viet = Vietnam.loc[:]
Viet['cases'] = Vietnam['cases'].cumsum()
Viet
# Out:
#           dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 10181  12/04/2020   12      4  2020      1       0                 Vietnam
# 10182  11/04/2020   11      4  2020      3       0                 Vietnam
# 10183  10/04/2020   10      4  2020      7       0                 Vietnam
# 10184  09/04/2020    9      4  2020      7       0                 Vietnam
# 10185  08/04/2020    8      4  2020     13       0                 Vietnam
# ...           ...  ...    ...   ...    ...     ...                     ...
# 10276  04/01/2020    4      1  2020    258       0                 Vietnam
# 10277  03/01/2020    3      1  2020    258       0                 Vietnam
# 10278  02/01/2020    2      1  2020    258       0                 Vietnam
# 10279  01/01/2020    1      1  2020    258       0                 Vietnam
# 10280  31/12/2019   31     12  2019    258       0                 Vietnam
#
#       geoId countryterritoryCode  popData2018
# ...

# %%
Cambodia = data[data.countriesAndTerritories =='Cambodia']
Cambodia
Cam = Cambodia.loc[:]
Cam['cases'] = Cambodia['cases'].cumsum()
Cam
# Out:
#          dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 1577  12/04/2020   12      4  2020      2       0                Cambodia
# 1578  11/04/2020   11      4  2020      3       0                Cambodia
# 1579  10/04/2020   10      4  2020      4       0                Cambodia
# 1580  09/04/2020    9      4  2020      5       0                Cambodia
# 1581  08/04/2020    8      4  2020      7       0                Cambodia
# ...          ...  ...    ...   ...    ...     ...                     ...
# 1667  04/01/2020    4      1  2020    122       0                Cambodia
# 1668  03/01/2020    3      1  2020    122       0                Cambodia
# 1669  02/01/2020    2      1  2020    122       0                Cambodia
# 1670  01/01/2020    1      1  2020    122       0                Cambodia
# 1671  31/12/2019   31     12  2019    122       0                Cambodia
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
Singapore = data[data.countriesAndTerritories =='Singapore']
Singapore
Si = Singapore.loc[:]
Si['cases'] = Singapore['cases'].cumsum()
Si
# Out:
#          dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 8473  12/04/2020   12      4  2020    390       2               Singapore
# 8474  11/04/2020   11      4  2020    390       0               Singapore
# 8475  10/04/2020   10      4  2020    676       0               Singapore
# 8476  09/04/2020    9      4  2020    818       0               Singapore
# 8477  08/04/2020    8      4  2020    924       0               Singapore
# ...          ...  ...    ...   ...    ...     ...                     ...
# 8572  04/01/2020    4      1  2020   2299       0               Singapore
# 8573  03/01/2020    3      1  2020   2299       0               Singapore
# 8574  02/01/2020    2      1  2020   2299       0               Singapore
# 8575  01/01/2020    1      1  2020   2299       0               Singapore
# 8576  31/12/2019   31     12  2019   2299       0               Singapore
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
Kenya = data[data.countriesAndTerritories =='Kenya']
Kenya
Ke = Kenya.loc[:]
Ke['cases'] = Kenya['cases'].cumsum()
Ke
# Out:
#          dateRep  day  mount  year  cases  deaths countriesAndTerritories  \
# 5315  12/04/2020   12      4  2020      2       0                   Kenya
# 5316  11/04/2020   11      4  2020      7       0                   Kenya
# 5317  10/04/2020   10      4  2020     12       1                   Kenya
# 5318  09/04/2020    9      4  2020     19       0                   Kenya
# 5319  08/04/2020    8      4  2020     33       2                   Kenya
# 5320  07/04/2020    7      4  2020     49       0                   Kenya
# 5321  06/04/2020    6      4  2020     65       0                   Kenya
# 5322  05/04/2020    5      4  2020     69       0                   Kenya
# 5323  04/04/2020    4      4  2020     81       1                   Kenya
# 5324  03/04/2020    3      4  2020    110       2                   Kenya
# 5325  02/04/2020    2      4  2020    132       0                   Kenya
# 5326  01/04/2020    1      4  2020    141       0                   Kenya
# ...

# %%
plt.plot(Kenya.dateRep , Ke.cases)
plt.plot(Singapore.dateRep , Si.cases)
plt.plot(Cambodia.dateRep , Cam.cases)
plt.plot(Laos.dateRep, La.cases)
plt.plot(Japan.dateRep , Jp.cases)
plt.plot(Brazil.dateRep, Bra.cases)
plt.plot(China.dateRep , Ch.cases)
plt.plot(Thailand.dateRep , th.cases)
plt.plot(Canada.dateRep , Ca.cases)
plt.plot(Vietnam.dateRep , Viet.cases)
plt.legend(['Kenya','Singapore','Cambodia','Laos','Japan','Brazil','China','Thailand','Canada','Vietnam'])
plt.xscale("linear")
plt.yscale("log")
plt.xlabel( 'day(count)')
plt.ylabel('cases(count)')
plt.title("The distribution of cases in each countries")
plt.show()

# %%
a=sum(Thailand["cases"])
b=sum(Thailand["deaths"])
c=a*100/69428524
d=b*100/a
c,d
# Out:
# (0.3029561740359049, 0.01806616018028126)

# %%
a=sum(China["cases"])
b=sum(China["deaths"])
e=a*100/1392730000
f=b*100/a
e,f
# Out:
# (0.2572865523109289, 0.09329370885609299)

# %%
a=sum(Canada["cases"])
b=sum(Canada["deaths"])
g=a*100/37058856
h=b*100/a
g,h
# Out:
# (5.970529689313669, 0.029512656997844174)

# %%
a=sum(Cambodia["cases"])
b=sum(Cambodia["deaths"])
i=a*100/16249798
j=b*100/a
i,j
# Out:
# (0.056548395247744, 0.0)

# %%
a=sum(Brazil["cases"])
b=sum(Brazil["deaths"])
k=a*100/20946933
l=b*100/a
k,l
# Out:
# (9.222853770525738, 0.05818091469301027)

# %%
a=sum(Singapore["cases"])
b=sum(Singapore["deaths"])
m=a*100/5638676
n=b*100/a
m,n
# Out:
# (3.7628336864895235, 0.0037704902579957958)

# %%
a=sum(Laos["cases"])
b=sum(Laos["deaths"])
o=a*100/7061507
p=b*100/a
o,p
# Out:
# (0.0024640632658156397, 0.0)

# %%
a=sum(Vietnam["cases"])
b=sum(Vietnam["deaths"])
q=a*100/95540395
r=b*100/a
q,r
# Out:
# (0.021245463764306187, 0.0)

# %%
a=sum(Japan["cases"])
b=sum(Japan["deaths"])
s=a*100/126529100
t=b*100/a
s,t
# Out:
# (0.005333160514063563, 1.4522821576763485)

# %%
a=sum(Kenya["cases"])
b=sum(Kenya["deaths"])
u=a*100/51393010
v=b*100/a
u,v
# Out:
# (0.0075788516765217685, 0.1797175866495507)

# %%
plt.scatter(e,f,color='r',\
           edgecolor='b',\
           linewidth = 3,\
           s =1000  ,\
           alpha = 0.3)
plt.scatter(k,l,color='G',\
           edgecolor='b',\
           s = 900 ,\
           alpha = 0.3)
plt.scatter( s,t ,color='w',\
           edgecolor='b',\
           s = 800 ,\
           alpha = 0.3)
plt.scatter ( q,r ,color='k',\
           edgecolor='b',\
           s = 700 ,\
           alpha = 0.3)
plt.scatter( c,d ,color='b',\
           edgecolor='b',\
           s = 600 ,\
           alpha = 0.3)
plt.scatter(u,v , color='k',\
           s = 500 ,\
           alpha = 0.3)
plt.scatter( g,h  ,color='c',\
           edgecolor='k',\
           s = 400 ,\
           alpha = 0.3)
plt.scatter( i,j,color='g',\
           edgecolor='k',\
           s = 300 ,\
           alpha = 0.3)

plt.scatter( m,n,color='m',\
           edgecolor='k',\
           s = 200 ,\
           alpha = 0.3)
plt.scatter(o,p ,color='y',\
           edgecolor='k',\
           s = 100 ,\
           alpha = 0.3)
plt.colorbar();
plt.xlabel("percent cases per whole people in each countries(%)",size = 8 )
plt.ylabel("percent dead per cases in each countries(%)",size = 8 )
plt.title("The scattering in each countries ")
plt.legend(("China","Brazil","Japan","Vietnam","Thailand","Kenya","Canada","Cambodia","Singapore","Laos"))
plt.savefig("plot.png")
plt.show()
